# %% [markdown]
# # Análisis de ventas y cancelaciones — Online Retail
#
# **Estado:** en desarrollo.
#
# Notebook reproducible para responder el encargo definido en `../docs/project_brief.md`.

# %% [markdown]
# ## 1. Resumen ejecutivo
#
# > Completar al final, únicamente con resultados ejecutados y validados.

# %% [markdown]
# ## 2. Contexto y métodos
#
# **Solicitante:** responsable comercial.
#
# **Decisión:** identificar dónde se genera el ingreso, qué riesgos afectan el desempeño y qué tres acciones conviene priorizar.
#
# **Fuente:** Online Retail, UCI Machine Learning Repository.

# %% [markdown]
# ### Supuestos y definiciones
#
# Documentar aquí las definiciones de venta, cancelación, ventas brutas, ventas netas, pedido y cliente después de comprobarlas contra los datos.

# %% [markdown]
# ## 3. Datos
#
# ### 3.1 Configuración
#
# Importar las librerías necesarias y declarar la ruta del archivo original.

# %%
# Tu código aquí

# %% [markdown]
# ### 3.2 Carga
#
# Cargar `../data/raw/Online Retail.xlsx` con pandas sin modificar el archivo.

# %%
# Tu código aquí

# %% [markdown]
# ### 3.3 Reconocimiento inicial
#
# Reportar dimensiones, columnas, tipos, primeras filas, periodo y granularidad: ¿qué representa exactamente una fila?

# %%
# Tu código aquí

# %% [markdown]
# ## 4. Calidad de datos
#
# Auditar faltantes, duplicados, cantidades, precios, cancelaciones, descripciones y clientes. Registrar las filas antes de limpiar.

# %%
# Tu código aquí

# %% [markdown]
# ## 5. Preparación
#
# Aplicar únicamente reglas justificadas. Separar ventas completadas y cancelaciones; crear campos derivados y registrar filas después de limpiar.

# %%
# Tu código aquí

# %% [markdown]
# ## 6. Validaciones
#
# Reconciliar ventas brutas, cancelaciones y ventas netas. Comprobar subtotales, duplicados, faltantes y cambios de filas.

# %%
# Tu código aquí

# %% [markdown]
# ## 7. Resultados
#
# ### 7.1 KPI generales
#
# Ventas brutas, valor cancelado, ventas netas, pedidos completados, ticket promedio y clientes identificados.

# %%
# Tu código aquí

# %% [markdown]
# ### 7.2 Evolución mensual
#
# Crear una tabla validada y un gráfico de línea.

# %%
# Tu código aquí

# %% [markdown]
# ### 7.3 Productos, países y clientes
#
# Crear rankings con agregaciones explícitas y verificar que sus subtotales sean coherentes.

# %%
# Tu código aquí

# %% [markdown]
# ### 7.4 Anomalía investigada
#
# Documentar una señal inesperada, cómo se comprobó y su posible explicación.

# %%
# Tu código aquí

# %% [markdown]
# ## 8. Conclusiones
#
# ### Hallazgos
#
# Pendiente.
#
# ### Recomendaciones
#
# Pendiente.
#
# ### Limitaciones
#
# Pendiente.
