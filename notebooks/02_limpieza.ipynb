# %% [markdown]
# # Limpieza reproducible — Online Retail
#
# Este notebook carga el archivo original, crea una copia de trabajo y documenta cada regla de limpieza.

# %%
# Importar pandas para leer y transformar datos.
import pandas as pd


# Cargar nuevamente el Excel original.
# El workspace fija la carpeta principal del proyecto como punto de inicio.
df_raw = pd.read_excel("data/raw/Online Retail.xlsx")


# Crear una copia independiente para aplicar la limpieza.
# df_raw permanecerá sin modificaciones.
df_clean = df_raw.copy()


# Confirmar que la copia contiene las mismas filas y columnas.
print("Original:", df_raw.shape)
print("Copia de trabajo:", df_clean.shape)

# %% [markdown]
# ## Reglas de limpieza
#
# Las reglas se agregarán después de validar descripciones, duplicados, devoluciones, precios no positivos y valores extremos.

# %%
# Próximo paso: completar descripciones únicamente cuando StockCode permita una relación confiable.
